# %%
a = 100
b = 5.5
c = "hello"
d = True
e = [1, 2, 3]
f = (1, 2, 3)
g = {1, 2, 3}

salary = input('Please enter your salary: ')
print(f'Your salary is {salary}')

print("Hello", "My", "Name", sep=":", end="?")
# Out:
# Please enter your salary: 12
# Your salary is 12
# Hello:My:Name?

# %%
name = "John"
print('id of name: ', id(name))
print('id of John Doe: ', id("John"))

name = 'pinto'
print('id of name: ', id(name))
print('id of pinto: ', id("pinto"))
# Out:
# id of name:  132095224352688
# id of John Doe:  132095224352688
# id of name:  132095224433648
# id of pinto:  132095224433648

# %%
#dec to bin
dec_1 = 88
bin_a = bin(dec_1)
print(bin_a)

#dec to oct
oct_a = oct(dec_1)
print(oct_a)

#dec to hex
hex_a = hex(dec_1)
print(hex_a)
# Out:
# 0b1011000
# 0o130
# 0x58

# %%
import math
print(math.sqrt(1))
print(math.exp(55))
print(math.cos(60))
# Out:
# 1.0
# 7.694785265142018e+23
# -0.9524129804151563

# %%
text = "Computer Engineering"
print(len(text))
print(text[-20:-12])
print(text[-20:])
print(text[0::2])

stext = "PythonProgramming"
result = stext.removeprefix("Python")
print(result)
result = stext.removesuffix("ming")
print(result)

stext1 = "IlovePython"
result = stext1.removeprefix("Ilove")
result1 = result.removesuffix("Python")
print(result, ":", result1)
# Out:
# 20
# Computer
# Computer Engineering
# Cmue niern
# Programming
# PythonProgram
# Python :

# %%
str1 = "sergkrejgewgr5yiowjehrjhg9r"
for i in str1:
  print(i)

str2 = "HELLO"
print((str1+str2)*3)
print(f"{str2}")
print(":::"%(str2)
# Out:
#   File "<ipython-input-33-611b3e6ee49e>", line 8
#     print(":::"%(str2)
#                       ^
# SyntaxError: incomplete input

# %%
multi_str = '''Hi!
My Student.
How are you today'''
print(multi_str)
# Out:
# Hi!
# My Student.
# How are you today

# %%
mylist = ['hello', 1, 2.2, True, 'a']
print(mylist)
mylist[1:3] = ['Python', 123, False]
print(mylist)
mylist.append('CPE')
mylist.insert(2, 'CPE499')
mylist.remove(True)
mylist.pop()
print(mylist)
mylist2 = [1, 2, 3, 4, 5, 6, 7, 8, 9]
mylist2.sort()
print(mylist2)
mylist2.sort(reverse=True)
print(mylist2)
print(mylist + mylist2)
# Out:
# ['hello', 1, 2.2, True, 'a']
# ['hello', 'Python', 123, False, True, 'a']
# ['hello', 'Python', 'CPE499', 123, False, 'a']
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [9, 8, 7, 6, 5, 4, 3, 2, 1]
# ['hello', 'Python', 'CPE499', 123, False, 'a', 9, 8, 7, 6, 5, 4, 3, 2, 1]
