# %%
import requests as rq
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2
import os
from PIL import Image


# path = "https://jsonplaceholder.typicode.com/posts"
# dataGet = rq.get(path).json()
# for i in dataGet:
#   print("UserId : ", i['userId'])
#   print("Id : ", i['id'])
#   print("Title : ", i['title'])
#   print("Body : ", i['body'])
#   print()

path = "https://random.dog/woof.json"
dataGet = rq.get(path).json()
x = dataGet['url']
print(x)
os.chdir(x)
# if(".jpg" in x):
#   path = "https://random.dog/woof.json"
#   dataGet = rq.get(path).json()
#   x = dataGet['url']
#   print(x)
# img_color = cv2.imread(dataGet['url'], cv2.COLOR_BGR2RGB)
# plt.imshow(img_color)
# plt.axis('off')
# plt.show()
# Out:
# https://random.dog/9dfecae7-5835-4d4f-a111-60b50faeee9a.mp4
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-736ca2b24c6d> in <cell line: 21>()
#      19 x = dataGet['url']
#      20 print(x)
# ---> 21 os.chdir(x)
#      22 # if(".jpg" in x):
#      23 #   path = "https://random.dog/woof.json"
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://random.dog/9dfecae7-5835-4d4f-a111-60b50faeee9a.mp4'
