# %%
import numpy as np
import matplotlib.pyplot as plt
inputX = float(input("Input = "))
# inputX = input("Input = ")
CalX = 2*inputX
x_data = [0.0, 6.0]
y_data = [0.0, 12.0]
x = np.array(x_data)
y = np.array(y_data)
plt.scatter(x, y)
# print(x)
plt.scatter(np.array([inputX, inputX, 0]), np.array([0, CalX, CalX]))
plt.plot(np.array([inputX, inputX, 0]), np.array([0, CalX, CalX]) , 'g')
plt.plot(x, y, 'r')
# plt.plot(0.0, 2.0, 'r')
plt.grid()
plt.show()
# Out:
# Input = 4
