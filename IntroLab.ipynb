# %%
xn1 = [75, 80, 64, 68, 82]
xn2 = [170, 165, 172, 161, 180]
xd1 = [44, 48, 51, 41, 57]
xd2 = [120, 152, 112, 118, 106]

# %%
w = (max(xd1) + min(xn1)) / 2
w = float(w)
h = (max(xd2) + min(xn2)) / 2
h = float(h)
print("w = ", w, "h = ", h)
# Out:
# w =  60.5 h =  156.5

# %%
wi = float(input("weight = "))
hi = float(input("height = "))
# Out:
# weight = 77
# height = 168

# %%
if ((wi > w) and (hi > h)):
  print("input = Normal class")
else:
  print("input = Dwarf class")
# Out:
# input = Normal class
