# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,0.999,num=100)
y = np.log(x/(1-x))
plt.plot(x,y)
plt.grid()
plt.show()
# Out:
# <ipython-input-1-1a0854a301b9>:4: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x/(1-x))
