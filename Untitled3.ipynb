# %%
def example(s):
    n = len(s)
    total = 0
    for j in range(n):
      for k in range(1+j):
        total += s[k]
    return total

s = [1, 2, 3, 4, 5]
print(example(s))
# Out:
# 35

# %%
# n_of_arr = int(input("Input your size of array"))
# arr = []

# for n in range(n_of_arr):
#   number = int(input("input your num"))
#   arr.insert(n, number)

# print(arr)
# Out:
# Input your size of array5
# input your num1
# input your num2
# input your num3
# input your num4
# input your num5
# [1, 2, 3, 4, 5]
