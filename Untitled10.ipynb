# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
model = LogisticRegression()

y_true = ["no", "yes", "yes", "yes", "no", "no", "no", "yes", "yes", "no"]
y_predict = ["yes", "yes", "no", "yes", "yes", "no", "yes", "yes", "yes", "no"]
cfmx = confusion_matrix(y_true, y_predict)

print(cfmx)

TN = cfmx[0, 0]
FP = cfmx[0, 1]
FN = cfmx[1, 0]
TP = cfmx[1 ,1]

Acc = (TP + TN) / len(y_true)
Error = (FP + FN) / len(y_true)

print("Acc : ", "{:.2f}".format(Acc))
print("Error : ", "{:.2f}".format(Error))
print(f"Acc : {format(Acc*100)} %")
print(f"Error : {format(Error*100)} %")
# Out:
# [[2 3]
#  [1 4]]
# Acc :  0.60
# Error :  0.40
# Acc : 60.0 %
# Error : 40.0 %
