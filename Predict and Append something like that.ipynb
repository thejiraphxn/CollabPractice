# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC

path = "/content/drive/MyDrive/CPE270/csv_test.csv"
df = pd.read_csv(path)


# x_1 = float(input())
# x_2 = float(input())
# x_predict = [[x_1, x_2]]
# y_predict = model.predict(x_predict)
# print("y Predict", y_predict[0])
# user_ans = str(input())
# if user_ans == "Yes":
#   new_row = {'size': x_1, 'price': x_2, 'sold': user_ans}
#   df = df.append(new_row, ignore_index=True)
# elif user_ans == "No":
#   new_row = {'size': x_1, 'price': x_2, 'sold': user_ans}
#   df = df.append(new_row, ignore_index=True)

df_yes = df[df['sold'] == 'Yes']
# print(df_yes)

x1 = df_yes['size']
x2 = df_yes['price']
plt.scatter(x1, x2, color='r', label='Yes')
# plt.show()

df_no = df[df['sold'] == 'No']
x1 = df_no['size']
x2 = df_no['price']
plt.scatter(x1, x2, color='w', marker='o', edgecolors='r', label='No')
# plt.show()
# print(df_yes['size'])


x = df[['size', 'price']]
y = df['sold']
model = SVC(kernel = "linear")
model.fit(x, y)

x_1 = float(input())
x_2 = float(input())
x_predict = [[x_1, x_2]]
y_predict = model.predict(x_predict)
plt.scatter(x_1, x_2, color='g', marker='p', edgecolors='g', label='NewRow')
plt.legend(loc='best')
print("Predict : ", y_predict[0])

b = model.intercept_[0]
w1 = model.coef_[0, 0]
w2 = model.coef_[0, 1]
x1 = df['size']


# user_ans = str(input("Your answer is "))
# if user_ans == "Yes":
#   if x_1 not in df["size"].values or x_2 not in df["price"].values :
#     # new_row = {'size': x_1, 'price': x_2, 'sold': user_ans}
#     # df = df.append(new_row, ignore_index=True)
#     new_row = pd.Series([x_1, x_2, y_predict[0]], index=df.columns, name="NewRow")
#     df = df.append(new_row, ignore_index=True)
# elif user_ans == "No":
#   # new_row = {'size': x_1, 'price': x_2, 'sold': user_ans}
#   # df = df.append(new_row, ignore_index=True)
#   new_row = pd.Series([x_1, x_2, y_predict[0]], index=df.columns, name="NewRow")
#   df = df.append(new_row, ignore_index=True)

user_ans = ''
while user_ans != "Yes" and user_ans != "No":
  user_ans = str(input("Your answer is "))
  if user_ans == "Yes":
    if x_1 not in df["size"].values or x_2 not in df["price"].values :
      # new_row = {'size': x_1, 'price': x_2, 'sold': user_ans}
      # df = df.append(new_row, ignore_index=True)
      new_row = pd.Series([x_1, x_2, user_ans], index=df.columns, name="NewRow")
      df = df.append(new_row, ignore_index=True)
  elif user_ans == "No":
    if x_1 not in df["size"].values or x_2 not in df["price"].values :
      # new_row = {'size': x_1, 'price': x_2, 'sold': user_ans}
      # df = df.append(new_row, ignore_index=True)
      new_row = pd.Series([x_1, x_2, user_ans], index=df.columns, name="NewRow")
      df = df.append(new_row, ignore_index=True)




x2 = (-b-(w1*x1)) / w2 # Plot Htperplane b+w1x1+w2X2 = 0
plt.plot(x1, x2, 'b-')
print(df)


# x2 = (1-b-(w1*x1)) / w2 # Plot Htperplane b+w1x1+w2X2 = 1
# plt.plot(x1, x2, 'r--')

# x2 = (-1-b-(w1*x1)) / w2 # Plot Htperplane b+w1x1+w2X2 = -1
# plt.plot(x1, x2, 'g--')
# Out:
# 5
# 8
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Predict :  No
# Your answer is No
# <ipython-input-4-aa7a62ccc690>:84: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)
#     size  price sold
# 0    1.0    2.2   No
# 1    1.2    2.3   No
# 2    4.2    2.4   No
# 3    5.5    3.5   No
# 4    5.6    6.6   No
# 5    7.5    7.3  Yes
# 6    7.6    7.5  Yes
# 7    7.8    7.8  Yes
# 8    8.8    9.5  Yes
# 9    9.9    9.9  Yes
# 10   5.0    8.0   No
