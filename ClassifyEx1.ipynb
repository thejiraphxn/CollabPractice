# %%
aw = [30.5, 34.2, 29.7, 27.8, 32.0]
ah = [73.6, 88.4, 69.2, 78.8, 82.5]
bw = [64.7, 72.4, 68.3, 71.0, 61.7]
bh = [142, 146, 153, 144, 152]

# %%
w = (max(aw) + min(bw)) / 2
w = float(w)
h = (max(ah) + min(bh)) / 2
h = float(h)
print("w = ", w, "h = ", h)
# Out:
# w =  47.95 h =  115.2

# %%
wi = float(input("weight = "))
hi = float(input("height = "))
# Out:
# weight = 57.4
# height = 123

# %%
if ((wi > w) and (hi > h)):
  print("input = Class B")
else:
  print("input = Class A")
# Out:
# input = Class B
